# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
#
# hello
#
# -87.8
#
# -
#
# /
#
# +
#
# 6

# %%
# * == Expression

# %%
# hello == string

# %%
# -87.8 ==  float

# %%
# - == Expression

# %%
# / == Expression

# %%
# + == Expression

# %%
# 6 == Integer

# %% [markdown]
# 2. What is the difference between string and variable?

# %%
String => String is a character base elements that store in the form of ABCD
# ex= "Hello world!"

# %%
Variable => Variable is a like a container that hold the values of like string, integer 
# var="Python"

# %% [markdown]
# 3. Describe three different data types.

# %%
# In Python, numeric data type represent the data which has numeric value. Numeric value can be integer, floating number or even complex numbers. These values are defined as int, float and complex class in Python.
# In Python, sequence is the ordered collection of similar or different data types. Sequences allows to store multiple values in an organized and efficient fashion. There are several sequence types in Python – String, List, Tuple

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %%
# An expression is a combination of operators and operands that is interpreted to produce some other value. In any programming language, an expression is evaluated as per the precedence of its operators.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %%
# Expression is made up of values, containers, and mathematical operators (operands) and the statement is just like a command that a python interpreter executes like print.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1

# %%
bacon=22
bacon+1
# Out:
# 23

# %% [markdown]
# 7. What should the values of the following two terms be?
#
# 'spam'+'spamspam'
#
# 'spam'*3

# %%
'spam'+'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam'*3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %%
# eggs is a valid variable name beacuse we cannot start variable with integer or any other special character. And we can start variable name using underscore(_).

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %%
# int() == for integer
# float( == for floating point
# str() == for string

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
#
# 'I have eaten'  + 99 + 'burritos'

# %%
# It will give you a error because you can only concatenate string to string not integer.

# %%
'I have eaten'+' 99 '+'burritos'
# Out:
# 'I have eaten 99 burritos'
